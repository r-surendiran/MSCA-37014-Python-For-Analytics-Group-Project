# %% [markdown]
# ### Oleksiy Anokhin (August 9, 2020)
#
# ### MSCA 37014 | Python for Analytics | Professor S. Chaudhary | Homework 3 (Team Project) | Data Cleaning

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set additional parameters
# Remove column display limits
pd.set_option('display.max_columns', None)
# pd.set_option('display.height', None)
pd.set_option('display.max_rows', None)
# pd.set_option('display.width', None)
plt.rcParams['figure.figsize'] = [15, 10]
sns.set_style("white")

# %%
# Read data
project = pd.read_csv('../Data/Raw/PERM_FY2020_Q3.csv', encoding = 'ISO-8859-1')
# Out:
# C:\Users\mattk\anaconda3\envs\msca\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (16,19,85,122) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Print data
project.head(5)
# Out:
#      CASE_NUMBER        CASE_STATUS RECEIVED_DATE DECISION_DATE REFILE  \
# 0  A-09245-62715             Denied      9/3/2009     4/30/2020      N
# 1  A-10119-96737  Certified-Expired     3/29/2010    10/18/2019      Y
# 2  A-10225-13679             Denied     8/10/2010     4/30/2020      N
# 3  A-11033-51540          Certified      2/3/2011     5/28/2020      N
# 4  A-11074-62984             Denied     3/10/2011     6/17/2020      N
#
#   ORIG_FILE_DATE PREVIOUS_SWA_CASE_NUMBER_STATE SCHD_A_SHEEPHERDER  \
# 0            NaN                            NaN                  N
# 1      9/15/2000                       MARYLAND                  N
# 2            NaN                            NaN                  N
# 3            NaN                            NaN                  N
# 4            NaN                            NaN                  N
#
#                  EMPLOYER_NAME        EMPLOYER_ADDRESS_1 EMPLOYER_ADDRESS_2  \
# 0       SATURN ENTERPRISES INC      2340 N WASHTENAW AVE                NaN
# 1                   FIL PARONG         13528 JAMIESON PL                NaN
# 2     GLENNS PLUMBING SERVICES         854 CUSTER STREET                NaN
# 3      SKILLNET SOLUTIONS INC.  1901 SOUTH BASCOM AVENUE          SUITE 600
# 4  R    L  CONSTRUCTION,  INC.    904  NEPPERHAN  AVENUE                NaN
#
#       EMPLOYER_CITY EMPLOYER_STATE_PROVINCE          EMPLOYER_COUNTRY  \
# 0           CHICAGO                ILLINOIS  UNITED STATES OF AMERICA
# 1        GERMANTOWN                MARYLAND  UNITED STATES OF AMERICA
# 2  N. VALLEY STREAM                NEW YORK  UNITED STATES OF AMERICA
# 3          CAMPBELL              CALIFORNIA  UNITED STATES OF AMERICA
# 4           YONKERS                NEW YORK  UNITED STATES OF AMERICA
#
#   EMPLOYER_POSTAL_CODE  EMPLOYER_PHONE EMPLOYER_PHONE_EXT  \
# 0                60647      7732769550                NaN
# 1                20874    301-515-8079                NaN
# 2                11580    516-561-3692                NaN
# 3                95008    408-523-6225                NaN
# 4                10703  (914) 423-2400                NaN
#
#    EMPLOYER_NUM_EMPLOYEES  EMPLOYER_YEAR_COMMENCED_BUSINESS NAICS_CODE  \
# 0                     2.0                            1998.0      23611
# 1                     0.0                            2009.0     531110
# 2                     3.0                            2002.0        NaN
# 3                    29.0                            1996.0     519190
# 4                    43.0                            1987.0     236115
#
#   FW_OWNERSHIP_INTEREST     EMP_CONTACT_NAME   EMP_CONTACT_ADDRESS_1  \
# 0                     N  zygmunt f oparowski    2340 n washtenaw ave
# 1                     N          FIL  PARONG       13528 JAMIESON PL
# 2                     N         DAVID  GLENN       854 CUSTER STREET
# 3                     N         Jack  Grover       1151 Sonora Court
# 4                     N   RITA  O ' SULLIVAN  904  NEPPERHAN  AVENUE
#
#   EMP_CONTACT_ADDRESS_2  EMP_CONTACT_CITY EMP_CONTACT_STATE_PROVINCE  \
# 0                   NaN           chicago                   ILLINOIS
# 1                   NaN        GERMANTOWN                   MARYLAND
# 2                   NaN  N. VALLEY STREAM                   NEW YORK
# 3               Suite 2         Sunnyvale                 CALIFORNIA
# 4                   NaN           YONKERS                   NEW YORK
#
#         EMP_CONTACT_COUNTRY EMP_CONTACT_POSTAL_CODE EMP_CONTACT_PHONE  \
# 0  UNITED STATES OF AMERICA                   60647        7732769550
# 1  UNITED STATES OF AMERICA                   20874   (301) 515-8079
# 2  UNITED STATES OF AMERICA                   11580     516-561-3692
# 3  UNITED STATES OF AMERICA                   94086     408-523-6225
# 4  UNITED STATES OF AMERICA                   10703   (914) 423-2400
#
#               EMP_CONTACT_EMAIL     AGENT_ATTORNEY_NAME  \
# 0  saturn_enterprises@yahoo.com  Christopher E Kurczaba
# 1                           NaN          WINSTON W TSAI
# 2                           NaN       DANIEL J SULLIVAN
# 3          jack@skillnetinc.com           Sonal  Kinger
# 4          ROSULLIVAN@RLCON.COM         VERNON L DUTTON
#
#    AGENT_ATTORNEY_FIRM_NAME AGENT_ATTORNEY_PHONE  AGENT_ATTORNEY_PHONE_EXT  \
# 0      Kurczaba Law Offices           7737740011                       NaN
# 1        WINSTON TSAI, ESQ.      (301) 320- 1888                       NaN
# 2  DANIEL J. SULLIVAN, ESQ.         631-732-3516                       NaN
# 3     Baker Law Corporation       (408) 971-0282                       NaN
# 4             NON  ATTORNEY       (718) 356-0592                       NaN
#
#    AGENT_ATTORNEY_ADDRESS_1 AGENT_ATTORNEY_ADDRESS_2 AGENT_ATTORNEY_CITY  \
# 0      6219 N Milwaukee Ave                      NaN             Chicago
# 1        6202 WINSTON DRIVE                      NaN            BETHESDA
# 2       815 HORSEBLOCK ROAD                      NaN        FARMINGVILLE
# 3  111 North Market Street,                Suite 300            San Jose
# 4          130  NANCY  LANE                      NaN      STATEN  ISLAND
#
#   AGENT_ATTORNEY_STATE_PROVINCE    AGENT_ATTORNEY_COUNTRY  \
# 0                      ILLINOIS  UNITED STATES OF AMERICA
# 1                      MARYLAND  UNITED STATES OF AMERICA
# 2                      NEW YORK  UNITED STATES OF AMERICA
# 3                    CALIFORNIA  UNITED STATES OF AMERICA
# 4                      NEW YORK  UNITED STATES OF AMERICA
#
#   AGENT_ATTORNEY_POSTAL_CODE           AGENT_ATTORNEY_EMAIL  PW_TRACK_NUMBER  \
# 0                      60646      kurczabalaw@sbcglobal.net              NaN
# 1                      20817            WINSTONTSAI@AOL.COM       MD00020468
# 2                      11738                   GWG8@AOL.COM  P10010067706999
# 3                      95113  sonal.kinger@bakerlawcorp.com  P10010223453518
# 4                      10307           MRDUTTON@VERIZON.NET  P10010244002722
#
#   PW_SOC_CODE                                       PW_SOC_TITLE  \
# 0  43-6011.00                           administrative assistant
# 1  49-9042.00                MAINTENANCE  REPAIR WORKER, GENERAL
# 2  47-2152.02                                            PLUMBER
# 3  15-1031.00                            Comp. SWE, Applications
# 4  47-1011.01  FIRST LINE SUPERVISORS  CONSTRUCTION TRADES WO...
#
#   PW_SKILL_LEVEL      PW_WAGE PW_UNIT_OF_PAY PW_WAGE_SOURCE  \
# 0        Level I       $14.49           Hour            OES
# 1      Level III       $19.36           Hour            OES
# 2       Level IV   $78,645.00           Year            OES
# 3       Level IV  $131,518.00           Year            OES
# 4        Level I   $53,643.00           Year            OES
#
#   PW_SOURCE_NAME_OTHER PW_DETERMINATION_DATE PW_EXPIRATION_DATE  \
# 0                  NaN             6/30/2009          9/28/2009
# 1                  NaN            12/15/2009         12/14/2010
# 2                  NaN              5/5/2010           8/3/2010
# 3                  NaN             8/27/2010          6/30/2011
# 4                  NaN             9/17/2010           7/1/2011
#
#   WAGE_OFFER_FROM WAGE_OFFER_TO WAGE_OFFER_UNIT_OF_PAY  \
# 0          $14.49           NaN                   Hour
# 1          $19.36           NaN                   Hour
# 2          $38.00        $40.00                   Hour
# 3     $131,518.00           NaN                   Year
# 4      $53,643.00           NaN                   Year
#
#        WORKSITE_ADDRESS_1    WORKSITE_ADDRESS_2        WORKSITE_CITY  \
# 0   2340 N. Washtenaw Ave                   NaN              Chicago
# 1    4242 RED MAPLE COUNT  4242 RED MAPLE COUNT         BURTONSVILLE
# 2       854 Custer Street                   NaN  North Valley Stream
# 3       1151 Sonora Court               Suite 2            Sunnyvale
# 4  904  NEPPERHAN  AVENUE                   NaN              YONKERS
#
#   WORKSITE_STATE WORKSITE_POSTAL_CODE                 JOB_TITLE  \
# 0       ILLINOIS                60647  administrative assistant
# 1       MARYLAND                20866      MAINTENANCE REPAIRER
# 2       NEW YORK                11580                   PLUMBER
# 3     CALIFORNIA                94086        Programmer Analyst
# 4       NEW YORK                10703          PROJECT  MANAGER
#
#   MINIMUM_EDUCATION JOB_EDUCATION_MIN_OTHER MAJOR_FIELD_OF_STUDY  \
# 0       High School                     NaN                  NaN
# 1       High School                     NaN                  NaN
# 2              None                     NaN                  NaN
# 3        Bachelor's                     NaN     Computer Science
# 4              None                     NaN                  NaN
#
#   REQUIRED_TRAINING  REQUIRED_TRAINING_MONTHS REQUIRED_FIELD_OF_TRAINING  \
# 0                 N                       NaN                        NaN
# 1                 N                       NaN                        NaN
# 2                 N                       NaN                        NaN
# 3                 N                       NaN                        NaN
# 4                 N                       NaN                        NaN
#
#   REQUIRED_EXPERIENCE  REQUIRED_EXPERIENCE_MONTHS ACCEPT_ALT_FIELD_OF_STUDY  \
# 0                   Y                        24.0                         N
# 1                   N                        24.0                         N
# 2                   Y                        24.0                         N
# 3                   Y                        60.0                         Y
# 4                   Y                        24.0                         N
#
#         ACCEPT_ALT_MAJOR_FLD_OF_STUDY ACCEPT_ALT_COMBO  \
# 0                                 NaN                N
# 1                                 NaN                N
# 2                                 NaN                N
# 3  SWE, Computer Applications or rltd                Y
# 4                                 NaN                N
#
#   ACCEPT_ALT_COMBO_EDUCATION                        ACCEPT_ALT_COMBO_ED_OTHER  \
# 0                        NaN                                              NaN
# 1                        NaN                                              NaN
# 2                        NaN                                              NaN
# 3                      Other  BS equivalency based on combination of diplomas
# 4                        NaN                                              NaN
#
#    ACCEPT_ALT_COMBO_EDUCATION_YRS ACCEPT_FOREIGN_EDUCATION  \
# 0                             NaN                        Y
# 1                             NaN                        Y
# 2                             NaN                        N
# 3                             5.0                        Y
# 4                             NaN                        N
#
#   ACCEPT_ALT_OCCUPATION  ACCEPT_ALT_OCCUPATION_MONTHS  \
# 0                     N                           NaN
# 1                     N                           NaN
# 2                     N                           NaN
# 3                     Y                          60.0
# 4                     N                           NaN
#
#                                 ACCEPT_ALT_JOB_TITLE  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Programmer Analyst, SWE, Junior Office, Lab As...
# 4                                                NaN
#
#   JOB_OPP_REQUIREMENTS_NORMAL FOREIGN_LANGUAGE_REQUIRED  \
# 0                           Y                         Y
# 1                           Y                         N
# 2                           Y                         N
# 3                           Y                         N
# 4                           Y                         N
#
#                                      SPECIFIC_SKILLS COMBINATION_OCCUPATION  \
# 0                         must communicate in Polish                      N
# 1  MUST HAVE 24 MONTHS EXPERIENCE FOR MAINTENANCE...                      N
# 2        ABILITY TO COMMUNICATE FLUENTLY IN SPANISH.                      N
# 3  Position requires Bachelors degree or foreign ...                      N
# 4                                                NaN                      N
#
#   OFFERED_TO_APPL_FOREIGN_WORKER FOREIGN_WORKER_LIVE_ON_PREM  \
# 0                              Y                           N
# 1                              Y                           N
# 2                              Y                           N
# 3                              Y                           N
# 4                              Y                           N
#
#   FOREIGN_WORKER_LIVE_IN_DOM_SER FOREIGN_WORKER_LIVE_IN_DOM_CNT  \
# 0                              N                            NaN
# 1                              N                            NaN
# 2                              N                              N
# 3                              N                            NaN
# 4                              N                            NaN
#
#   PROFESSIONAL_OCCUPATION APP_FOR_COLLEGE_U_TEACHER COMPETITIVE_PROCESS  \
# 0                       N                         N                 NaN
# 1                       N                         N                   N
# 2                       N                         N                   N
# 3                       Y                         N                 NaN
# 4                       N                         N                 NaN
#
#   BASIC_RECRUITMENT_PROCESS TEACHER_SELECT_DATE TEACHER_PUB_JOURNAL_NAME  \
# 0                       NaN                 NaN                      NaN
# 1                         N                 NaN                      NaN
# 2                         N                 NaN                      NaN
# 3                       NaN                 NaN                      NaN
# 4                       NaN                 NaN                      NaN
#
#   ADD_RECRUIT_INFORMATION SWA_JOB_ORDER_START_DATE SWA_JOB_ORDER_END_DATE  \
# 0                     NaN                6/23/2009              7/27/2009
# 1                     NaN                 1/6/2010               2/7/2010
# 2                     NaN                 5/3/2010              8/13/2010
# 3                     NaN                 9/9/2010             10/11/2010
# 4                     NaN                11/3/2010              12/3/2010
#
#   SUNDAY_EDITION_NEWSPAPER   FIRST_NEWSPAPER_NAME  \
# 0                        Y        Chicago Tribune
# 1                        Y    WASHINGTON EXAMINER
# 2                        Y                NY Post
# 3                        Y  San Jose Mercury News
# 4                        Y        NEW  YORK  POST
#
#   FIRST_ADVERTISEMENT_START_DATE SECOND_NEWSPAPER_AD_NAME  \
# 0                       7/5/2009          Chicago Tribune
# 1                       2/7/2010      WASHINGTON EXAMINER
# 2                       6/6/2010                  NY Post
# 3                     10/10/2010    San Jose Mercury News
# 4                     10/17/2010          NEW  YORK  POST
#
#   SECOND_ADVERTISEMENT_TYPE SECOND_AD_START_DATE JOB_FAIR_FROM_DATE  \
# 0                 Newspaper            7/12/2009                NaN
# 1                 Newspaper            2/14/2010                NaN
# 2                 Newspaper            6/13/2010                NaN
# 3                 Newspaper           10/17/2010                NaN
# 4                 Newspaper           10/24/2010                NaN
#
#   JOB_FAIR_TO_DATE ON_CAMPUS_RECRUITING_FROM_DATE  \
# 0              NaN                            NaN
# 1              NaN                            NaN
# 2              NaN                            NaN
# 3              NaN                            NaN
# 4              NaN                            NaN
#
#   ON_CAMPUS_RECRUITING_TO_DATE EMPLOYER_WEBSITE_FROM_DATE  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                  9/14/2010
# 4                          NaN                        NaN
#
#   EMPLOYER_WEBSITE_TO_DATE PRO_ORG_AD_FROM_DATE PRO_ORG_ADVERTISEMENT_TO_DATE  \
# 0                      NaN                  NaN                           NaN
# 1                      NaN                  NaN                           NaN
# 2                      NaN                  NaN                           NaN
# 3                9/28/2010                  NaN                           NaN
# 4                      NaN                  NaN                           NaN
#
#   JOB_SEARCH_WEBSITE_FROM_DATE JOB_SEARCH_WEBSITE_TO_DATE  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                   10/10/2010                 10/15/2010
# 4                          NaN                        NaN
#
#   PVT_EMPLOYMENT_FIRM_FROM_DATE PVT_EMPLOYMENT_FIRM_TO_DATE  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#   EMPLOYEE_REF_PROG_FROM_DATE EMPLOYEE_REFERRAL_PROG_TO_DATE  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                   9/13/2010                      9/27/2010
# 4                         NaN                            NaN
#
#   CAMPUS_PLACEMENT_FROM_DATE CAMPUS_PLACEMENT_TO_DATE  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#   LOCAL_ETHNIC_PAPER_FROM_DATE LOCAL_ETHNIC_PAPER_TO_DATE  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#   RADIO_TV_AD_FROM_DATE RADIO_TV_AD_TO_DATE EMP_RECEIVED_PAYMENT  \
# 0                   NaN                 NaN                    N
# 1                   NaN                 NaN                    N
# 2                   NaN                 NaN                    N
# 3                   NaN                 NaN                    N
# 4                   NaN                 NaN                    N
#
#   PAYMENT_DETAILS BARGAINING_REP_NOTIFIED POSTED_NOTICE_AT_WORKSITE  \
# 0             NaN                     NaN                         Y
# 1             NaN                     NaN                         Y
# 2             NaN                     NaN                         Y
# 3             NaN                     NaN                         Y
# 4             NaN                     NaN                         Y
#
#   LAYOFF_IN_PAST_SIX_MONTHS US_WORKERS_CONSIDERED COUNTRY_OF_CITIZENSHIP  \
# 0                         N                   NaN                 POLAND
# 1                         N                   NaN            PHILIPPINES
# 2                         N                     N            EL SALVADOR
# 3                         N                   NaN                  INDIA
# 4                         N                   NaN                IRELAND
#
#   FOREIGN_WORKER_BIRTH_COUNTRY CLASS_OF_ADMISSION FOREIGN_WORKER_EDUCATION  \
# 0                       POLAND                B-2              High School
# 1                  PHILIPPINES                B-2              High School
# 2                  EL SALVADOR                EWI                     None
# 3                        INDIA               H-1B                    Other
# 4                      IRELAND                NaN              High School
#
#             FOREIGN_WORKER_EDUCATION_OTHER  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  EQUIV. OF BS BASED ON COMBO OF DIPLOMAS
# 4                                      NaN
#
#                    FOREIGN_WORKER_INFO_MAJOR  FOREIGN_WORKER_YRS_ED_COMP  \
# 0                                    GENERAL                      1996.0
# 1                                HIGH SCHOOL                      1991.0
# 2                                        NaN                         NaN
# 3  ELECTRONICS ENGINEERING  COMPUTER SCIENCE                      1996.0
# 4                                    GENERAL                      1995.0
#
#                         FOREIGN_WORKER_INST_OF_ED  \
# 0                              LICEUM EKONOMICZNE
# 1                SAN JACINTO NATIONAL HIGH SCHOOL
# 2                                             NaN
# 3  SHRI BAHAGUBHAI MAFATLAL POLYTECHNIC INSTITUTE
# 4                          FALCARRAGH HIGH SCHOOL
#
#   FOREIGN_WORKER_ED_INST_ADD_1 FOREIGN_WORKER_ED_INST_ADD_2  \
# 0              UL. JANA GOETZA                          NaN
# 1        10 BARANGAY GUIBEL ST                          NaN
# 2                          NaN                          NaN
# 3      IRLA LANE, VILE PARLE W                          NaN
# 4                          NaN                          NaN
#
#   FOREIGN_WORKER_ED_INST_CITY FOREIGN_WORKER_ED_INST_STATE_P  \
# 0                     BRZESKO                            NaN
# 1                 SAN JACINTO                       BARANGAY
# 2                         NaN                            NaN
# 3                      MUMBAI                    MAHARASHTRA
# 4                  FALCARRAGH                            NaN
#
#   FOREIGN_WORKER_ED_INST_COUNTRY FOREIGN_WORKER_ED_INST_POST_CD  \
# 0                         POLAND                         32-800
# 1                    PHILIPPINES                            NaN
# 2                            NaN                            NaN
# 3                          INDIA                         400056
# 4                        IRELAND                            NaN
#
#   FOREIGN_WORKER_TRAINING_COMP FOREIGN_WORKER_REQ_EXPERIENCE  \
# 0                          NaN                             Y
# 1                          NaN                             Y
# 2                            N                             Y
# 3                          NaN                             Y
# 4                          NaN                             Y
#
#   FOREIGN_WORKER_ALT_ED_EXP FOREIGN_WORKER_ALT_OCC_EXP  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                         N                          N
# 3                         Y                          Y
# 4                       NaN                        NaN
#
#   FOREIGN_WORKER_EXP_WITH_EMPL FOREIGN_WORKER_EMPL_PAY_FOR_ED  \
# 0                            N                              N
# 1                            N                              N
# 2                            N                              N
# 3                            N                              N
# 4                            N                              N
#
#   FOREIGN_WORKER_CURR_EMPLOYED EMPLOYER_COMPLETED_APPLICATION  \
# 0                            N                              N
# 1                            N                              N
# 2                            N                              N
# 3                            Y                              N
# 4                            N                              N
#
#             PREPARER_NAME   PREPARER_TITLE                 PREPARER_EMAIL  \
# 0  Christopher E Kurczaba         Attorney      kurczabalaw@sbcglobal.net
# 1          WINSTON W TSAI  ATTORNEY AT LAW            WINSTONTSAI@AOL.COM
# 2       DANIEL J SULLIVAN         ATTORNEY                   GWG8@AOL.COM
# 3           Sonal  Kinger  Attorney at Law  sonal.kinger@bakerlawcorp.com
# 4         DENISE S DUTTON      NONATTORNEY                            NaN
#
#    EMP_INFO_DECL_NAME           EMP_INFO_DECL_TITLE
# 0  Zygmunt  Oparowski                     President
# 1         FIL  PARONG             HEAD OF HOUSEHOLD
# 2        DAVID  GLENN                         OWNER
# 3        Jack  Grover  VP of Finance and Operations
# 4   RITA  O  SULLIVAN                       MANAGER

# %%
# Check rows
project.shape
# Out:
# (71942, 154)

# %%
# Select only meaninful columns
project = project[['CASE_STATUS', 'RECEIVED_DATE', 'DECISION_DATE', 'EMPLOYER_CITY', 'EMPLOYER_STATE_PROVINCE',
                   'EMPLOYER_NUM_EMPLOYEES', 'EMP_CONTACT_CITY', 'EMP_CONTACT_STATE_PROVINCE', 'EMP_CONTACT_POSTAL_CODE',
                   'AGENT_ATTORNEY_NAME', 'AGENT_ATTORNEY_FIRM_NAME', 'PW_SKILL_LEVEL', 'PW_WAGE', 'PW_UNIT_OF_PAY',
                   'WORKSITE_CITY', 'WORKSITE_STATE', 'WORKSITE_POSTAL_CODE', 'REQUIRED_EXPERIENCE', 
                   'REQUIRED_EXPERIENCE_MONTHS', 'WAGE_OFFER_UNIT_OF_PAY', 'PW_SOC_CODE', 
                   'FOREIGN_LANGUAGE_REQUIRED', 'FIRST_NEWSPAPER_NAME', 'SECOND_NEWSPAPER_AD_NAME', 
                   'COUNTRY_OF_CITIZENSHIP', 'FOREIGN_WORKER_BIRTH_COUNTRY', 'CLASS_OF_ADMISSION', 
                   'FOREIGN_WORKER_EDUCATION', 'FOREIGN_WORKER_INFO_MAJOR', 'FOREIGN_WORKER_INST_OF_ED',
                  'EMPLOYER_YEAR_COMMENCED_BUSINESS', 'NAICS_CODE', 'MINIMUM_EDUCATION']]

# %%
# Print types
project.dtypes
# Out:
# CASE_STATUS                          object
# RECEIVED_DATE                        object
# DECISION_DATE                        object
# EMPLOYER_CITY                        object
# EMPLOYER_STATE_PROVINCE              object
# EMPLOYER_NUM_EMPLOYEES              float64
# EMP_CONTACT_CITY                     object
# EMP_CONTACT_STATE_PROVINCE           object
# EMP_CONTACT_POSTAL_CODE              object
# AGENT_ATTORNEY_NAME                  object
# AGENT_ATTORNEY_FIRM_NAME             object
# PW_SKILL_LEVEL                       object
# PW_WAGE                              object
# PW_UNIT_OF_PAY                       object
# WORKSITE_CITY                        object
# WORKSITE_STATE                       object
# WORKSITE_POSTAL_CODE                 object
# REQUIRED_EXPERIENCE                  object
# REQUIRED_EXPERIENCE_MONTHS          float64
# WAGE_OFFER_UNIT_OF_PAY               object
# PW_SOC_CODE                          object
# FOREIGN_LANGUAGE_REQUIRED            object
# FIRST_NEWSPAPER_NAME                 object
# SECOND_NEWSPAPER_AD_NAME             object
# COUNTRY_OF_CITIZENSHIP               object
# FOREIGN_WORKER_BIRTH_COUNTRY         object
# CLASS_OF_ADMISSION                   object
# FOREIGN_WORKER_EDUCATION             object
# FOREIGN_WORKER_INFO_MAJOR            object
# FOREIGN_WORKER_INST_OF_ED            object
# EMPLOYER_YEAR_COMMENCED_BUSINESS    float64
# NAICS_CODE                           object
# MINIMUM_EDUCATION                    object
# dtype: object

# %%
# All column names to lower
project.columns = project.columns.str.lower()

# %%
# Print
project.head(5)
# Out:
#          case_status received_date decision_date     employer_city  \
# 0             Denied      9/3/2009     4/30/2020           CHICAGO
# 1  Certified-Expired     3/29/2010    10/18/2019        GERMANTOWN
# 2             Denied     8/10/2010     4/30/2020  N. VALLEY STREAM
# 3          Certified      2/3/2011     5/28/2020          CAMPBELL
# 4             Denied     3/10/2011     6/17/2020           YONKERS
#
#   employer_state_province  employer_num_employees  emp_contact_city  \
# 0                ILLINOIS                     2.0           chicago
# 1                MARYLAND                     0.0        GERMANTOWN
# 2                NEW YORK                     3.0  N. VALLEY STREAM
# 3              CALIFORNIA                    29.0         Sunnyvale
# 4                NEW YORK                    43.0           YONKERS
#
#   emp_contact_state_province emp_contact_postal_code     agent_attorney_name  \
# 0                   ILLINOIS                   60647  Christopher E Kurczaba
# 1                   MARYLAND                   20874          WINSTON W TSAI
# 2                   NEW YORK                   11580       DANIEL J SULLIVAN
# 3                 CALIFORNIA                   94086           Sonal  Kinger
# 4                   NEW YORK                   10703         VERNON L DUTTON
#
#    agent_attorney_firm_name pw_skill_level      pw_wage pw_unit_of_pay  \
# 0      Kurczaba Law Offices        Level I       $14.49           Hour
# 1        WINSTON TSAI, ESQ.      Level III       $19.36           Hour
# 2  DANIEL J. SULLIVAN, ESQ.       Level IV   $78,645.00           Year
# 3     Baker Law Corporation       Level IV  $131,518.00           Year
# 4             NON  ATTORNEY        Level I   $53,643.00           Year
#
#          worksite_city worksite_state worksite_postal_code  \
# 0              Chicago       ILLINOIS                60647
# 1         BURTONSVILLE       MARYLAND                20866
# 2  North Valley Stream       NEW YORK                11580
# 3            Sunnyvale     CALIFORNIA                94086
# 4              YONKERS       NEW YORK                10703
#
#   required_experience  required_experience_months wage_offer_unit_of_pay  \
# 0                   Y                        24.0                   Hour
# 1                   N                        24.0                   Hour
# 2                   Y                        24.0                   Hour
# 3                   Y                        60.0                   Year
# 4                   Y                        24.0                   Year
#
#   pw_soc_code foreign_language_required   first_newspaper_name  \
# 0  43-6011.00                         Y        Chicago Tribune
# 1  49-9042.00                         N    WASHINGTON EXAMINER
# 2  47-2152.02                         N                NY Post
# 3  15-1031.00                         N  San Jose Mercury News
# 4  47-1011.01                         N        NEW  YORK  POST
#
#   second_newspaper_ad_name country_of_citizenship  \
# 0          Chicago Tribune                 POLAND
# 1      WASHINGTON EXAMINER            PHILIPPINES
# 2                  NY Post            EL SALVADOR
# 3    San Jose Mercury News                  INDIA
# 4          NEW  YORK  POST                IRELAND
#
#   foreign_worker_birth_country class_of_admission foreign_worker_education  \
# 0                       POLAND                B-2              High School
# 1                  PHILIPPINES                B-2              High School
# 2                  EL SALVADOR                EWI                     None
# 3                        INDIA               H-1B                    Other
# 4                      IRELAND                NaN              High School
#
#                    foreign_worker_info_major  \
# 0                                    GENERAL
# 1                                HIGH SCHOOL
# 2                                        NaN
# 3  ELECTRONICS ENGINEERING  COMPUTER SCIENCE
# 4                                    GENERAL
#
#                         foreign_worker_inst_of_ed  \
# 0                              LICEUM EKONOMICZNE
# 1                SAN JACINTO NATIONAL HIGH SCHOOL
# 2                                             NaN
# 3  SHRI BAHAGUBHAI MAFATLAL POLYTECHNIC INSTITUTE
# 4                          FALCARRAGH HIGH SCHOOL
#
#    employer_year_commenced_business naics_code minimum_education
# 0                            1998.0      23611       High School
# 1                            2009.0     531110       High School
# 2                            2002.0        NaN              None
# 3                            1996.0     519190        Bachelor's
# 4                            1987.0     236115              None

# %%
# Check NAs
project.isnull().sum(axis = 0)
# As we can see, there are some NAs
# Out:
# case_status                             0
# received_date                           5
# decision_date                           0
# employer_city                           0
# employer_state_province                 1
# employer_num_employees                  9
# emp_contact_city                        1
# emp_contact_state_province              3
# emp_contact_postal_code                 4
# agent_attorney_name                     0
# agent_attorney_firm_name             5956
# pw_skill_level                       4303
# pw_wage                                 8
# pw_unit_of_pay                         10
# worksite_city                           4
# worksite_state                          4
# worksite_postal_code                    5
# required_experience                     2
# required_experience_months          31220
# wage_offer_unit_of_pay                  3
# pw_soc_code                            46
# foreign_language_required               0
# first_newspaper_name                 1641
# second_newspaper_ad_name             1652
# country_of_citizenship                  6
# foreign_worker_birth_country            5
# class_of_admission                   5854
# foreign_worker_education                5
# foreign_worker_info_major            9160
# foreign_worker_inst_of_ed            8669
# employer_year_commenced_business       27
# naics_code                             49
# minimum_education                       6
# dtype: int64

# %%
# Remove $ symbol
project = project.replace(r'[<$]', '', regex = True)

# %%
# Print
project.head(5)
# Out:
#          case_status received_date decision_date     employer_city  \
# 0             Denied      9/3/2009     4/30/2020           CHICAGO
# 1  Certified-Expired     3/29/2010    10/18/2019        GERMANTOWN
# 2             Denied     8/10/2010     4/30/2020  N. VALLEY STREAM
# 3          Certified      2/3/2011     5/28/2020          CAMPBELL
# 4             Denied     3/10/2011     6/17/2020           YONKERS
#
#   employer_state_province  employer_num_employees  emp_contact_city  \
# 0                ILLINOIS                     2.0           chicago
# 1                MARYLAND                     0.0        GERMANTOWN
# 2                NEW YORK                     3.0  N. VALLEY STREAM
# 3              CALIFORNIA                    29.0         Sunnyvale
# 4                NEW YORK                    43.0           YONKERS
#
#   emp_contact_state_province emp_contact_postal_code     agent_attorney_name  \
# 0                   ILLINOIS                   60647  Christopher E Kurczaba
# 1                   MARYLAND                   20874          WINSTON W TSAI
# 2                   NEW YORK                   11580       DANIEL J SULLIVAN
# 3                 CALIFORNIA                   94086           Sonal  Kinger
# 4                   NEW YORK                   10703         VERNON L DUTTON
#
#    agent_attorney_firm_name pw_skill_level     pw_wage pw_unit_of_pay  \
# 0      Kurczaba Law Offices        Level I       14.49           Hour
# 1        WINSTON TSAI, ESQ.      Level III       19.36           Hour
# 2  DANIEL J. SULLIVAN, ESQ.       Level IV   78,645.00           Year
# 3     Baker Law Corporation       Level IV  131,518.00           Year
# 4             NON  ATTORNEY        Level I   53,643.00           Year
#
#          worksite_city worksite_state worksite_postal_code  \
# 0              Chicago       ILLINOIS                60647
# 1         BURTONSVILLE       MARYLAND                20866
# 2  North Valley Stream       NEW YORK                11580
# 3            Sunnyvale     CALIFORNIA                94086
# 4              YONKERS       NEW YORK                10703
#
#   required_experience  required_experience_months wage_offer_unit_of_pay  \
# 0                   Y                        24.0                   Hour
# 1                   N                        24.0                   Hour
# 2                   Y                        24.0                   Hour
# 3                   Y                        60.0                   Year
# 4                   Y                        24.0                   Year
#
#   pw_soc_code foreign_language_required   first_newspaper_name  \
# 0  43-6011.00                         Y        Chicago Tribune
# 1  49-9042.00                         N    WASHINGTON EXAMINER
# 2  47-2152.02                         N                NY Post
# 3  15-1031.00                         N  San Jose Mercury News
# 4  47-1011.01                         N        NEW  YORK  POST
#
#   second_newspaper_ad_name country_of_citizenship  \
# 0          Chicago Tribune                 POLAND
# 1      WASHINGTON EXAMINER            PHILIPPINES
# 2                  NY Post            EL SALVADOR
# 3    San Jose Mercury News                  INDIA
# 4          NEW  YORK  POST                IRELAND
#
#   foreign_worker_birth_country class_of_admission foreign_worker_education  \
# 0                       POLAND                B-2              High School
# 1                  PHILIPPINES                B-2              High School
# 2                  EL SALVADOR                EWI                     None
# 3                        INDIA               H-1B                    Other
# 4                      IRELAND                NaN              High School
#
#                    foreign_worker_info_major  \
# 0                                    GENERAL
# 1                                HIGH SCHOOL
# 2                                        NaN
# 3  ELECTRONICS ENGINEERING  COMPUTER SCIENCE
# 4                                    GENERAL
#
#                         foreign_worker_inst_of_ed  \
# 0                              LICEUM EKONOMICZNE
# 1                SAN JACINTO NATIONAL HIGH SCHOOL
# 2                                             NaN
# 3  SHRI BAHAGUBHAI MAFATLAL POLYTECHNIC INSTITUTE
# 4                          FALCARRAGH HIGH SCHOOL
#
#    employer_year_commenced_business naics_code minimum_education
# 0                            1998.0      23611       High School
# 1                            2009.0     531110       High School
# 2                            2002.0        NaN              None
# 3                            1996.0     519190        Bachelor's
# 4                            1987.0     236115              None

# %%
# Save as csv
project.to_csv('../Data/Clean/project_data_cleaned.csv')
